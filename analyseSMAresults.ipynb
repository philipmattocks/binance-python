# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/philipmattocks/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
def plot_sma_results(csv_file, first_n_rows = 0):

        
    #plt.scatter(df['x'], df['sma5'],color='red')
    df = pd.read_csv(csv_file)
    if first_n_rows > 0:
        df = df[:first_n_rows]
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    plt.rcParams["figure.figsize"] = (20,3)
    plt.plot( 'date', 'sma_50', data=df, color='red', linewidth=1)
    plt.plot( 'date', 'sma_200', data=df, color='blue', linewidth=1)
    plt.plot( 'date', 'price', data=df, color='green', linewidth=1)
    plt.scatter(df['date'], df['long'], color='red',s=50)
    plt.scatter(df['date'], df['short'], color='blue',s=50)
    plt.xticks(rotation=45)
    plt.show()

# %%
df = pd.read_csv('live_test.csv')
df
# Out:
#                             date     price      sma_50      sma_200  long  \
# 0     2021-11-15 11:53:06.074278  65737.80         NaN          NaN   NaN
# 1     2021-11-15 11:53:06.987089  65737.80         NaN          NaN   NaN
# 2     2021-11-15 11:53:07.915137  65737.80         NaN          NaN   NaN
# 3     2021-11-15 11:53:08.900937  65737.81         NaN          NaN   NaN
# 4     2021-11-15 11:53:09.961777  65737.81         NaN          NaN   NaN
# ...                          ...       ...         ...          ...   ...
# 3590  2021-11-15 13:05:47.849892  65722.25  65721.4744  65707.23450   NaN
# 3591  2021-11-15 13:05:48.815017  65725.44  65721.9832  65707.36175   NaN
# 3592  2021-11-15 13:05:50.114283  65726.83  65722.5198  65707.49590   NaN
# 3593  2021-11-15 13:05:50.796606  65726.83  65723.0564  65707.63005   NaN
# 3594  2021-11-15 13:05:51.893662  65734.06  65723.7378  65707.80035   NaN
#
#       short
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
plot_sma_results('live_test.csv')
